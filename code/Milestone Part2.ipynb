# %%
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt
import random
plt.style.use("ggplot")

# %%
data1 =pd.read_csv("processed_individual_cases_Sep20th2020.csv")

# %%
data2 =pd.read_csv("processed_location_Sep20th2020.csv")

# %%
#Plotting number of confirmed cases by country
groupByCountry= data2.groupby(by=["Country_Region"]).sum()
plt.figure(figsize=(10, 30))
plt.xlabel('Number of Cases')
plt.ylabel('Countries')
plt.plot(groupByCountry['Confirmed'],groupByCountry.index,'.')
plt.savefig('confirmedCases_byCountry.jpg')

# %% [markdown]
# # AGE FILTERING

# %%
#Age is defined in 362 different patterns
len(np.unique(data1['age'].astype(str)))
np.unique(data1['age'].astype(str))

#First we will try to solve the pattern which contains age in shape 'X-Y'
agefiltered= data1['age'].astype(str)

def getFilter1(df):
    return re.findall('\d+',df)

arrayData=  agefiltered.apply(getFilter1)

#Now we randomly assign the age for pattern X-Y between X and Y
for i in range(len(arrayData)):
    if(len(arrayData[i])>1):
        value1= int(arrayData[i][0])
        value2= int(arrayData[i][1])
        if(value2!=0 and value2>=value1):
            randomAge= random.randint(value1, value2)
            data1['age'][i]=str(randomAge)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Now we are still left with different pattern. We we do it manually.
for i in range(len(data1)):
    if (data1['age'][i]=='18-') :
        data1['age'][i]=str(random.randint(1, 18))
    elif (data1['age'][i]=='21-') :
        data1['age'][i]=str(random.randint(1, 21))
    elif (data1['age'][i]=='55-') :
        data1['age'][i]=str(random.randint(1, 55))
    elif (data1['age'][i]=='65-') :
        data1['age'][i]=str(random.randint(1, 65))
    elif (data1['age'][i]=='80+'):
        data1['age'][i]=str(random.randint(80, 100))
    elif (data1['age'][i]=='80-'):
        data1['age'][i]=str(random.randint(60, 80))
    elif (data1['age'][i]=='85+'):
        data1['age'][i]=str(random.randint(85, 100))
    elif(data1['age'][i]=='60-') :
        data1['age'][i]=str(random.randint(40, 60))
    elif (data1['age'][i]=='90+'):
        data1['age'][i]=str(random.randint(90, 110))
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Now we will do our last filter which contains 'months'
for i in range(len(data1)):
    if (data1['age'][i]=='11 month') :
        data1['age'][i]=str(11/12)
    elif (data1['age'][i]=='18 month') :
        data1['age'][i]=str(18/12)
    elif (data1['age'][i]=='4 months') :
        data1['age'][i]=str(4/12)
    elif (data1['age'][i]=='5 month') :
        data1['age'][i]=str(5/12)
    elif (data1['age'][i]=='6 months'):
        data1['age'][i]=str(6/12)
    elif (data1['age'][i]=='8 month'):
        data1['age'][i]=str(8/12)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#data1['age']=data1['age'].astype(str).astype(float)

# %%
data2
# Out:
#      Province_State      Country_Region          Last_Update        Lat  \
# 0               NaN         Afghanistan  2020-09-20 04:22:56  33.939110
# 1               NaN             Albania  2020-09-20 04:22:56  41.153300
# 2               NaN             Algeria  2020-09-20 04:22:56  28.033900
# 3               NaN             Andorra  2020-09-20 04:22:56  42.506300
# 4               NaN              Angola  2020-09-20 04:22:56 -11.202700
# ...             ...                 ...                  ...        ...
# 3949            NaN  West Bank and Gaza  2020-09-20 04:22:56  31.952200
# 3950            NaN      Western Sahara  2020-09-20 04:22:56  24.215500
# 3951            NaN               Yemen  2020-09-20 04:22:56  15.552727
# 3952            NaN              Zambia  2020-09-20 04:22:56 -13.133897
# 3953            NaN            Zimbabwe  2020-09-20 04:22:56 -19.015438
#
#           Long_  Confirmed  Deaths  Recovered   Active        Combined_Key  \
# 0     67.709953      38919    1437      32576   4906.0         Afghanistan
# 1     20.168300      12226     358       6888   4980.0             Albania
# 2      1.659600      49623    1665      34923  13035.0             Algeria
# 3      1.521800       1564      53       1164    347.0             Andorra
# 4     17.873900       3901     147       1445   2309.0              Angola
# ...         ...        ...     ...        ...      ...                 ...
# 3949  35.233200      35003     253      23446  11304.0  West Bank and Gaza
# 3950 -12.885800         10       1          8      1.0      Western Sahara
# 3951  48.516388       2026     585       1221    220.0               Yemen
# 3952  27.849332      14070     330      13365    375.0              Zambia
# 3953  29.154857       7672     225       5914   1533.0            Zimbabwe
#
#       Incidence_Rate  Case-Fatality_Ratio
# 0          99.976005             3.692284
# 1         424.838418             2.928186
# 2         113.162645             3.355299
# 3        2024.202420             3.388747
# 4          11.869312             3.768265
# ...              ...                  ...
# 3949      686.142828             0.722795
# 3950        1.674116            10.000000
# 3951        6.792738            28.874630
# 3952       76.534126             2.345416
# 3953       51.618366             2.932742
#
# [3954 rows x 12 columns]

# %% [markdown]
# # BELOW CODE WILL HELP DURING MERGE

# %%
#For province value which are left 'nan' or 'State Unassigned' will be assigned the value of their country.
for i in range(len(data1)):
    if(str(data1['province'][i])=='nan' or  data1['province'][i]=='State Unassigned'):
        data1['province'][i]=data1['country'][i]
#Same approch for data2
for i in range(len(data2)):
    if(str(data2['Country_Region'][i])=='nan'):
        data2['Country_Region'][i]=data2['Province_State'][i]
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#Remove Two rows whose all data is NAN
data1=data1[data1['province'].notnull()]
data1=data1.reset_index(drop=True)

# %%
data1['age']=data1['age'].astype(str).astype(np.float)
removedNanData = data1[data1['age'].notnull()].reset_index(drop=True)
groupByProvince= removedNanData.groupby(by=["province"]).mean()

# %%
#Setting the age value by mean of that province which it belongs to.
for i in range(len(data1)):
    if str(data1['age'][i])== 'nan':
        for j in range(len(groupByProvince)):
            if(data1['province'][i]==groupByProvince.index[j]):
                data1['age'][i]=groupByProvince['age'][j]
                break;
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#There is still age left which who does not have mean of province then thet will be assigned mean value of their country.
data1[data1['age'].isnull()].reset_index(drop=True)
removedNanData = data1[data1['age'].notnull()].reset_index(drop=True)
groupByCountry= removedNanData.groupby(by=["country"]).mean()

# %%
#Left over age 'nan' values will be assigned by mean of country.
for i in range(len(data1)):
    if(str(data1['age'][i])=='nan'):
        for j in range(len(groupByCountry)):
            if (data1['country'][i]==groupByCountry.index[j]):
                data1['age'][i]=groupByCountry['age'][j]
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Last filter for outliers where ages are greater than 150 which is not possible. 
for i in range(len(data1)):
    if(str(data1['age'][i])=='nan' or data1['age'][i]>150):
        data1['age'][i]=random.randint(0, 95)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#Age histogram plot
plt.figure(figsize=(10, 10))
plt.hist(data1['age'], bins = 50,rwidth=0.9,alpha=0.9, color='#FF5733')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(axis='y',alpha=0.5)
plt.title('Age group Frequency')
plt.savefig('AgeFrequency.jpg')

# %% [markdown]
# # FILTERING SEX

# %%
removedNanData = data1[data1['sex'].notnull()].reset_index(drop=True)
groupByProvince= removedNanData.groupby(by=["province"]).mean()

# %%
x=data1.groupby(['province','sex'])
data1['sex']=data1['sex'].astype(str).count()
data1['sex']=data1['sex'].astype(str)

# %%
#Sex value is not defined then the ratio is used for that province to set 'nan' value to male or female
for i in range(len(data1)):
    if(str(data1['sex'][i])=='nan'):
        for j in range(len(x)):
            if(str(data1['province'])==x.index[j][0]):
                if(x[i]>0 and x[i+1]>0):
                    maleRatio= (x[i]/(x[i]+x[i+1])) *100
                    randomValue= random.randint(1, 100)
                    if(randomValue<maleRatio):
                        data1['sex'][i]='male'
                    else:
                        data1['sex'][i]='female'

# %% [markdown]
# # FILTERING FOR INCIDENCE RATE

# %%
#Filtering of insidence_Rate
#removedNanData = data1[data1['sex'].notnull()].reset_index(drop=True)
groupByProvince= data2.groupby(by=["Province_State"]).mean()
data2[data2['Incidence_Rate'].isnull()]
for i in range(len(data2)):
    if(str(data2['Incidence_Rate'][i])=='nan' ):
        for j in range(len(groupByProvince)) :
            if data2['Province_State'][i]==groupByProvince.index[j]:
                data2['Incidence_Rate'][i]=groupByProvince['Incidence_Rate'][j]
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
#Now remaining values are filtered by taking country in account
groupByCountry= data2.groupby(by=["Country_Region"]).mean()
data2[data2['Incidence_Rate'].isnull()]
for i in range(len(data2)):
    if(str(data2['Incidence_Rate'][i])=='nan' ):
        for j in range(len(groupByCountry)) :
            if data2['Country_Region'][i]==groupByCountry.index[j]:
                data2['Incidence_Rate'][i]=groupByCountry['Incidence_Rate'][j]
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Filtering of Case-Fatality_Ratio
for i in range(len(data2)):
    if(str(data2['Case-Fatality_Ratio'][i])=='nan' ):
        for j in range(len(groupByProvince)) :
            if data2['Province_State'][i]==groupByProvince.index[j]:
                data2['Case-Fatality_Ratio'][i]=groupByProvince['Case-Fatality_Ratio'][j]
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Manually filtering remaining data
str(data2['Incidence_Rate'][0])=='nan'
data2[data2['Case-Fatality_Ratio'].isnull()]
data2= data2[data2.index!=3071].reset_index(drop=True)
data2= data2[data2.index!=251].reset_index(drop=True)
data2= data2[data2.index!=3941].reset_index(drop=True)
data2= data2[data2.index!=594].reset_index(drop=True)
data2= data2[data2.index!=265].reset_index(drop=True)
data2= data2[data2.index!=67].reset_index(drop=True)
data2.loc[data2.index==175,'Incidence_Rate']= float('nan')
data2.loc[data2.index==359,'Incidence_Rate']= float('nan')

# %%
#Giving latitude and longitude based on province
for i in range(len(data2)):
    if(str(data2['Lat'][i])=='nan' or str(data2['Long_'][i])=='nan' ):
        for j in range(len(groupByProvince)) :
            if data2['Province_State'][i]==groupByProvince.index[j]:
                data2['Lat'][i]=groupByProvince['Lat'][j]
                data2['Long_'][i]=groupByProvince['Long_'][j]
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
#Latitude and Longitude based on country if Province is not there, we need to be near our main region
for i in range(len(data2)):
    if(str(data2['Lat'][i])=='nan' or str(data2['Long_'][i])=='nan' ):
        for j in range(len(groupByCountry)) :
            if data2['Country_Region'][i]==groupByCountry.index[j]:
                data2['Lat'][i]=groupByCountry['Lat'][j]
                data2['Long_'][i]=groupByCountry['Long_'][j]
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
#We have no idea baout the rest 4, so we used unknown here'
data2[data2['Lat'].isnull()]
data2.loc[data2.index==175,'Lat']= float('nan')
data2.loc[data2.index==175,'Long_']= float('nan')
data2.loc[data2.index==359,'Lat']= float('nan')
data2.loc[data2.index==359,'Long_']=float('nan')

# %%
#We calculated that only didn't have anything on active cases, and all recovered. Safe to say that 0 are active.
data2[data2['Active'].isnull()]
data2.loc[data2.index==95,'Active']= np.float(0)

# %%
for i in range(len(data2)):
    if(str(data2['Province_State'][i])=='nan' or  data2['Province_State'][i]=='State Unassigned'):
        data2['Province_State'][i]=data2['Country_Region'][i]
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for i in range(len(data1)):
    if(str(data1['date_confirmation'][i])=='nan'):
        data1['date_confirmation'][i] = 'Unknown'

for i in range(len(data1)):
    if(str(data1['additional_information'][i])=='nan'):
        data1['additional_information'][i] = 'Unknown'

for i in range(len(data1)):
    if(str(data1['source'][i])=='nan'):
        data1['source'][i] = 'Unknown'
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# # FINDING OUTLIERS

# %%
for i in range(len(data1)):
    if str(data1['age'][i]) != 'Unknown' :
        if float(data1['age'][i])  > 150 :
            print(i,"  Value hai  ",data1['age'][i])
#plt.figure(figsize=(20,20))            
#plt.plot(data2[''])  
#data2[data2.index==736]
#print(data2['Incidence_Rate'][987])
#data2['Incidence_Rate'][1048]
#data2[3272]

# %% [markdown]
# # ISOLATION TREE FOR OUTLIERS

# %%
#model=IsolationForest(n_estimators=50, max_samples='auto', contamination=float(0.1),max_features=1.0)
#model.fit(data2[['Confirmed']])
#data2[data2['Incidence_Rate'].isnull()]

# %%
#data2['scores']=model.decision_function(data2[['Confirmed']])
#data2['anomaly']=model.predict(data2[['Confirmed']])

# %%
#anomaly=data2.loc[data2['anomaly']==-1]
#anomaly_index=list(anomaly.index)
#print(anomaly)

# %%
#print("Accuracy percentage:", 100*list(data2['anomaly']).count(-1)/(outliers_counter))

# %%
data2
# Out:
#           Province_State      Country_Region          Last_Update        Lat  \
# 0            Afghanistan         Afghanistan  2020-09-20 04:22:56  33.939110
# 1                Albania             Albania  2020-09-20 04:22:56  41.153300
# 2                Algeria             Algeria  2020-09-20 04:22:56  28.033900
# 3                Andorra             Andorra  2020-09-20 04:22:56  42.506300
# 4                 Angola              Angola  2020-09-20 04:22:56 -11.202700
# ...                  ...                 ...                  ...        ...
# 3943  West Bank and Gaza  West Bank and Gaza  2020-09-20 04:22:56  31.952200
# 3944      Western Sahara      Western Sahara  2020-09-20 04:22:56  24.215500
# 3945               Yemen               Yemen  2020-09-20 04:22:56  15.552727
# 3946              Zambia              Zambia  2020-09-20 04:22:56 -13.133897
# 3947            Zimbabwe            Zimbabwe  2020-09-20 04:22:56 -19.015438
#
#           Long_  Confirmed  Deaths  Recovered   Active        Combined_Key  \
# 0     67.709953      38919    1437      32576   4906.0         Afghanistan
# 1     20.168300      12226     358       6888   4980.0             Albania
# 2      1.659600      49623    1665      34923  13035.0             Algeria
# 3      1.521800       1564      53       1164    347.0             Andorra
# 4     17.873900       3901     147       1445   2309.0              Angola
# ...         ...        ...     ...        ...      ...                 ...
# 3943  35.233200      35003     253      23446  11304.0  West Bank and Gaza
# 3944 -12.885800         10       1          8      1.0      Western Sahara
# 3945  48.516388       2026     585       1221    220.0               Yemen
# 3946  27.849332      14070     330      13365    375.0              Zambia
# 3947  29.154857       7672     225       5914   1533.0            Zimbabwe
#
#       Incidence_Rate  Case-Fatality_Ratio
# 0          99.976005             3.692284
# 1         424.838418             2.928186
# 2         113.162645             3.355299
# 3        2024.202420             3.388747
# 4          11.869312             3.768265
# ...              ...                  ...
# 3943      686.142828             0.722795
# 3944        1.674116            10.000000
# 3945        6.792738            28.874630
# 3946       76.534126             2.345416
# 3947       51.618366             2.932742
#
# [3948 rows x 12 columns]

# %% [markdown]
# # Deleting latitude who are not between (-90,90) and longitude between (-180,180)

# %%
for i in range(len(data2)):
    if str(data2['Lat'][i]) != 'Unknown' :
        if float(data2['Lat'][i])  > 90 :
            print(i,"  Value hai  ",data2['Lat'][i])

data2['Lat'].max()
# Out:
# 71.7069

# %% [markdown]
# # Checking for outliers in case-Fatality_Rates

# %%
for i in range(len(data2)):
    if str(data2['Case-Fatality_Ratio'][i]) != 'Unknown' :
        if float(data2['Case-Fatality_Ratio'][i])  > 70 :
            print(i,"  Value hai  ",data2['Case-Fatality_Ratio'][i])
# Out:
# 1817   Value hai   89.47368421052632

# %%
data2= data2[data2.index!=3059].reset_index(drop=True)

# %% [markdown]
# # Finding outliers for active cases as it cannot be negative

# %%
for i in range(len(data2)):
    if str(data2['Active'][i]) != 'Unknown' :
        if float(data2['Active'][i])  < 0 :
            print(i,"  Value hai  ",data2['Active'][i])

data2= data2[data2.index!=2551].reset_index(drop=True)
data2= data2[data2.index!=1866].reset_index(drop=True)
data2= data2[data2.index!=1421].reset_index(drop=True)
data2= data2[data2.index!=467].reset_index(drop=True)
# Out:
# 467   Value hai   -594513.0
# 1421   Value hai   -225.0
# 1866   Value hai   -11.0
# 2551   Value hai   -16.0

# %% [markdown]
# # Doing 1.4 to Find data for USA

# %%
dataUS=data2[data2['Country_Region']=='US']
ProvinceSum = dataUS.groupby(by=['Province_State']).sum()
ProvinceMean = dataUS.groupby(by=['Province_State']).mean()

# %%
for i in range(len(ProvinceSum)):
    ProvinceSum['Case-Fatality_Ratio'][i]= (ProvinceSum['Deaths'][i] / ProvinceSum['Confirmed'][i])*100
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ProvinceSum['Incidence_Rate'] = ProvinceMean['Incidence_Rate']
ProvinceSum = ProvinceSum.drop(['Lat', 'Long_'],axis=1)
ProvinceSum
# Out:
#                           Confirmed  Deaths  Recovered    Active  \
# Province_State
# Alabama                      144164    2437          0  141727.0
# Alaska                         6729      45          0    6684.0
# Arizona                      212942    5451          0  207491.0
# Arkansas                      75160    1181          0   73979.0
# California                   783313   15018          0  768295.0
# Colorado                      64336    2013          0   62323.0
# Connecticut                   55527    4492          0   51035.0
# Delaware                      19449     621          0   18828.0
# Diamond Princess                 49       0          0      49.0
# District of Columbia          14902     619          0   14283.0
# Florida                      681233   13287          0  667946.0
# Georgia                      305021    6599          0  298422.0
# Grand Princess                  103       3          0     100.0
# Guam                           2074      31          0    2043.0
# Hawaii                        11326     120          0   11206.0
# Idaho                         37247     441          0   36806.0
# Illinois                     275041    8672          0  266369.0
# Indiana                      110759    3278          0  107481.0
# Iowa                          79804    1265          0   78520.0
# Kansas                        52486     594          0   51892.0
# Kentucky                      61106    1108          0   59998.0
# Louisiana                    160283    5342          0  154941.0
# Maine                          5034     139          0    4895.0
# Maryland                     119744    3865          0  115879.0
# Massachusetts                127181    9295          0  117886.0
# Michigan                     128087    6969          0  121118.0
# Minnesota                     88721    2015          0   86706.0
# Mississippi                   93087    2809          0   90278.0
# Missouri                     112864    1825          0  111039.0
# Montana                       10163     156          0   10007.0
# Nebraska                      40797     442          0   40355.0
# Nevada                        75419    1528          0   73891.0
# New Hampshire                  7920     438          0    7482.0
# New Jersey                   199309   16064          0  183245.0
# New Mexico                    27512     847          0   26665.0
# New York                     449038   33065          0  415973.0
# North Carolina               192247    3235          0  189012.0
# North Dakota                  17607     192          0   17415.0
# Northern Mariana Islands         68       2          0      66.0
# Ohio                         143547    4612          0  138935.0
# Oklahoma                      75804     943          0   74861.0
# Oregon                        30342     521          0   29821.0
# Pennsylvania                 154236    7940          0  146296.0
# Puerto Rico                   40310       0          0   40310.0
# Rhode Island                  23620    1088          0   22532.0
# South Carolina               137240    3188          0  134052.0
# South Dakota                  18444     200          0   18244.0
# Tennessee                    181439    2216          0  179223.0
# Texas                        707940   15051          0  692889.0
# Utah                          62852     440          0   62412.0
# Vermont                        1710      58          0    1652.0
# Virgin Islands                 1257      19          0    1238.0
# Virginia                     139546    2988          0  136558.0
# Washington                    82199    2037          0   80162.0
# West Virginia                 13889     311          0   13578.0
# Wisconsin                     97279    1238          0   96041.0
# Wyoming                        4781      49          0    4731.0
#
#                           Incidence_Rate  Case-Fatality_Ratio
# Province_State
# Alabama                      3239.932554             1.690436
# Alaska                        681.806753             0.668747
# Arizona                      2927.250679             2.559852
# Arkansas                     2564.972414             1.571315
# California                   1544.858420             1.917241
# Colorado                      881.209708             3.128886
# Connecticut                  1197.530911             8.089758
# Delaware                     2033.110711             3.192966
# Diamond Princess             1709.174171             0.000000
# District of Columbia         2111.515567             4.153805
# Florida                      3523.976717             1.950434
# Georgia                      3019.372118             2.163458
# Grand Princess               1709.174171             2.912621
# Guam                         1262.870748             1.494696
# Hawaii                        418.446064             1.059509
# Idaho                        1579.963290             1.183988
# Illinois                     1441.003581             3.152984
# Indiana                      1346.471783             2.959579
# Iowa                         2100.445798             1.585134
# Kansas                       1383.117107             1.131730
# Kentucky                     1120.724105             1.813243
# Louisiana                    3733.903132             3.332855
# Maine                         225.154147             2.761224
# Maryland                     1498.364317             3.227719
# Massachusetts                1429.430750             7.308482
# Michigan                      685.158730             5.440833
# Minnesota                    1261.090529             2.271165
# Mississippi                  3625.542448             3.017607
# Missouri                     1432.336152             1.616990
# Montana                       874.908131             1.534980
# Nebraska                     1279.159628             1.083413
# Nevada                        830.808648             2.026015
# New Hampshire                 340.254754             5.530303
# New Jersey                   1989.386941             8.059847
# New Mexico                   1051.624045             3.078657
# New York                     1019.670358             7.363519
# North Carolina               1780.936122             1.682731
# North Dakota                 1678.142061             1.090475
# Northern Mariana Islands      123.313506             2.941176
# Ohio                          979.085183             3.212885
# Oklahoma                     1607.759976             1.243998
# Oregon                        850.064628             1.717092
# Pennsylvania                  744.383817             5.147955
# Puerto Rico                   967.198281             0.000000
# Rhode Island                 1180.066538             4.606266
# South Carolina               2792.093174             2.322938
# South Dakota                 1617.141081             1.084363
# Tennessee                    2709.573838             1.221347
# Texas                        1996.520644             2.126028
# Utah                         1710.098827             0.700057
# Vermont                       203.133446             3.391813
# Virgin Islands               1171.831301             1.511535
# Virginia                     1552.538985             2.141229
# Washington                   1135.256154             2.478132
# West Virginia                 599.240468             2.239182
# Wisconsin                    1172.414045             1.272628
# Wyoming                       801.660985             1.024890

# %%
individualUS = data1[data1['country']=='United States']

# %%
individualUS = individualUS.merge(ProvinceSum,how='left',left_on=['province'], right_on=['Province_State'])

# %%
data1[data1['country']=='United States']
# Out:
#               age     sex     province        country   latitude   longitude  \
# 20      31.000000  557362      Vermont  United States  44.461123  -73.081581
# 89      66.000000  557362      Florida  United States  29.057307  -81.184136
# 151     61.400000  557362  Mississippi  United States  30.768985  -89.589712
# 260     86.000000  557362   Washington  United States  47.491332 -121.803640
# 294     24.000000  557362      Florida  United States  27.928952  -82.721790
# ...           ...     ...          ...            ...        ...         ...
# 557188   0.000000  557362      Florida  United States  26.152188  -80.487715
# 557193  53.666667  557362     Virginia  United States  37.325836  -76.782770
# 557233  49.000000  557362      Florida  United States  26.152188  -80.487715
# 557312  39.000000  557362      Florida  United States  26.152188  -80.487715
# 557346  67.000000  557362      Florida  United States  25.613599  -80.565963
#
#        date_confirmation               additional_information  \
# 20            16.03.2020               Self-isolating at home
# 89            07.03.2020  in isolation; recent travel history
# 151           19.03.2020                              Unknown
# 260           06.03.2020         Resident of Ida Culver House
# 294           26.03.2020                              Unknown
# ...                  ...                                  ...
# 557188        24.03.2020                              Unknown
# 557193        12.03.2020                              Unknown
# 557233        18.03.2020                              Unknown
# 557312        15.03.2020                              Unknown
# 557346        25.03.2020                              Unknown
#
#                                                    source          outcome
# 20      https://www.healthvermont.gov/media/newsroom/v...  nonhospitalized
# 89      http://www.floridahealth.gov/diseases-and-cond...  nonhospitalized
# 151     https://msdh.ms.gov/msdhsite/_static/14,0,420....  nonhospitalized
# 260     https://www.kiro7.com/news/local/coronavirus-w...         deceased
# 294                     https://floridahealthcovid19.gov/  nonhospitalized
# ...                                                   ...              ...
# 557188                  https://floridahealthcovid19.gov/  nonhospitalized
# 557193  http://www.vdh.virginia.gov/surveillance-and-i...  nonhospitalized
# 557233   http://floridadisaster.org/globalassets/covid-19  nonhospitalized
# 557312                                            Unknown  nonhospitalized
# 557346                  https://floridahealthcovid19.gov/  nonhospitalized
#
# [5176 rows x 10 columns]

# %% [markdown]
# # Checking for countries that are in ocations but not in cases

# %%
check1 = data1.groupby(by =['country']).mean()
check2 = data2.groupby(by=['Country_Region']).mean()

# %%
count = 0

for i in range(len(check1)):
    toy="nan"
    for j in range(len(check2)):
        if check1.index[i]==check2.index[j] :
            count=count +1
            toy=check1.index[i]
    if(toy=='nan'):
        print(check1.index[i])
# Out:
# Czech Republic
# Democratic Republic of the Congo
# Puerto Rico
# Republic of Congo
# Reunion
# South Korea
# United States

# %% [markdown]
# # 8 found with distinct names in the dataset

# %%
#Czech Republic = Czechia
#Democratic republic of Congo = congo kinhasa 
#republic of COngo is congo brazzville
#Puerto rico put in province and set country US FOR CASES
#set reuinion to province and country to france in cases
#change korea,south to South Korea
#Taiwan is same as country and province with no data
#change united states to US

# %%
Checking for province
# Out:
#   File "<ipython-input-66-6d7a8c682081>", line 1
#     Checking for province
#                ^
# SyntaxError: invalid syntax

# %%
check1 = data1.groupby(by =['province']).mean()
check2 = data2.groupby(by=['Province_State']).mean()

# %%
count = 0

for i in range(len(check1)):
    toy="nan"
    for j in range(len(check2)):
        if str(check1.index[i]).lower()==str(check2.index[j]).lower() :
            count=count +1
            toy=check1.index[i]
    if(toy=='nan'):
        print(check1.index[i])
# Out:
# ABANCAY
# ACOMAYO
# AIJA
# ANGARAES
# ANTA
# ANTABAMBA
# ANTONIO RAIMONDI
# ATALAYA
# AYABACA
# AYMARAES
# AZANGARO
# Aargau
# Abia
# Abra
# Abu Dhabi
# Abuja
# Acobamba
# Adamawa
# Addis Ababa
# Afar
# Agder
# Agusan Del Norte
# Aichi Prefecture
# Ain Defla
# Ain Temouchent
# Aklan
# Akmola
# Akwa Ibom
# Aland Hospital District
# Albay
# Alborz
# Alentejo
# Algarve
# Alger
# Algiers
# Almaty
# Alto Amazonas
# Alto Parana
# Amambay
# Ambo
# Amhara
# Anambra
# Andahuaylas
# Andalucia
# Annaba
# Antique
# Apayao
# Archipielago de San Andres Providencia y Santa Catalina
# Ardebil
# Artemisa
# Ascope
# Ashanti Region
# Asuncion
# Attica Prefecture
# Atyrau
# Australia
# Auvergne-Rhone-Alpes
# Azores
# Azuay
# BOLOGNESI
# Bagua
# Banes
# Bangkok Metropolis
# Baraguá
# Barranca
# Barranquilla
# Barranquilla DE
# Basel
# Basel-Landschaft
# Basque Country
# Bataan
# Batangas
# Batna
# Bauchi
# Bauta
# Bavaria
# Bayelsa
# Bechar
# Beirut
# Bejaia
# Bellavista
# Benguet
# Benue
# Bern
# Bimini
# Biskra
# Blida
# Bogota
# Bogota DC
# Bohol
# Bongara
# Boqueron
# Bordj Bou-Arreridj
# Borno
# Bouira
# Boumerdes
# Bourgogne-Franche-Comte
# Boyeros
# Brazil
# Bretagne
# Brittany
# Brussels
# Buenaventura DE
# Buenos Aires
# Bukidnon
# Bulacan
# Bulawayo
# Bulawayo Metro
# Bungoma
# Burgenland
# Busan
# Bushehr
# CABA
# CAJABAMBA
# CAJATAmbo
# CANCHIS
# CANGALLO
# CARABAYA
# CARLOS FERMIN FITZCARRALD
# CASTROVIRREYNA
# CAnaS
# CELENDIN
# CHEPEN
# CHINCHEROS
# CHOTA
# CHUCUITO
# CHUMBIVILCAS
# CHURCAMPA
# CONDESUYOS
# CONDORCANQUI
# CONTUMAZA
# CORONGO
# COTABAMBAS
# CUTERVO
# Caaguazu
# Caazapa
# Cabaiguán
# Cagayan
# Calca
# Camaguey
# Camagüey
# Camajuaní
# Camana
# Camarines Norte
# Camarines Sur
# Camiguin
# Canar
# Canary Islands
# Canete
# Canindeyu
# Canta
# Capital Region
# Capiz
# Caraveli
# Carchi
# Carhuaz
# Carinthia
# Cartagena
# Cartagena DT y C
# Casma
# Castilla
# Castilla La Mancha
# Castilla–La Mancha
# Cataluna
# Catanduanes
# Cavite
# Caylloma
# Cebu
# Cebu Province
# Central
# Central Bohemian Region
# Central Finland Hospital District
# Central Ostrobothnia Hospital District
# Central Region
# Centre-Val de Loire
# Centro
# Cerro
# Chachapoyas
# Chaco
# Chanchamayo
# Chernivtsi
# Chiba Prefecture
# Chiclayo
# Chile
# Chimaltenango
# Chimborazo
# Chincha
# Chipas
# Chlef
# Chubut
# Chupaca
# Ciego de Avila
# Ciego de Ávila
# Cienfuegos
# Ciudad de Buenos Aires
# Cochabamba
# Colombia
# Compostela Valley
# Concepcion
# Constantine
# Contralmirante Villar
# Contramaestre
# Cordillera
# Coronel Portillo
# Corrientes
# Corse
# Corsica
# Cotabato
# Cotopaxi
# Cotorro
# Czech Republic
# DOS DE MAYO
# Daegu
# Daejeon
# Dagupan
# Dakar
# Daniel Alcides Carrion
# Datem del Maranon
# Davao Del Norte
# Davao Del Sur
# Davao Occidental
# Davao Oriental
# Davao de Oro
# Davao del Sur
# Delta
# Democratic Republic of the Congo
# Diez de Octubre
# Dire Dawa
# Djelfa
# EL COLLAO
# EL DORADO
# ESPINAR
# East Azarbaijan
# East Kazakhstan
# Eastern Cape
# Ebonyi
# Edo
# Ekiti
# El Oro
# El Oued
# El Tarf
# Entre Rios
# Enugu
# Esfahan
# Esmeralda
# Esmeraldas
# Estado de Mexico
# Etela-Savo Hospital District
# Far Eastern
# Fars
# Federal Capital Territory
# Ferrenafe
# Flanders
# Florencia
# Free State
# Fribourg
# GRAN CHIMU
# GRAU
# Galapagos
# Gangwon
# Gauteng
# General Sanchez Cerro
# Geneva
# Ghardaia
# Gibara
# Gilan
# Golestan
# Gombe
# Gorj
# Gozo
# Grand Bahama
# Grand Est
# Granma
# Graubunden
# Greater Accra Region
# Greater Caracas
# Guaira
# Guanabacoa
# Guantanamo
# Guantánamo
# Guatemala City
# Guayas
# Guelma
# Guerero
# Gwangju
# Gyeonggi
# HUACAYBAMBA
# HUALLAGA
# HUAMALIES
# HUANCA SANCOS
# HUANCABAMBA
# HUANCANE
# HUANTA
# HUAROCHIRI
# HUAYTARA
# Habana Vieja
# Hamadan
# Harare
# Harare Metro
# Harju
# Hauts-de-France
# Havana
# Helsinki and Uusimaa Hospital District
# Herat
# Hesse
# Hiiu
# Hoguin
# Holguin
# Holguín
# Holy Cross
# Hormozgan
# Hradec Kralove
# Hradec Kralove Region
# Hualgayoc
# Huamanga
# Huancayo
# Huaral
# Huaraz
# Huari
# Huarmey
# Huaura
# Huaylas
# ILO
# ISLAY
# Ida-Viru
# Ifugao
# Ilam
# Ile-de-France
# Illizi
# Ilocos Norte
# Ilocos Sur
# Iloilo
# Iloilo Province
# Imbabura
# Imo
# Incheon
# India
# Innlandet
# Isabel
# Isabela
# Isla de la Juventud
# Isle of Youth
# Ita-Savo Hospital District
# Itapua
# JAUJA
# JORGE BASADRE
# JULCAN
# Jaen
# Jambyl
# Jamtland
# Japan
# Jarva
# Jeju
# Jigawa
# Jijel
# Jogeva
# Johor
# Jujuy
# Jura
# Kaduna
# Kainuu Hospital District
# Kanagawa Prefecture
# Kano
# Kanta-Hame Hospital District
# Karaganda
# Karbala
# Karlovy Vary
# Karlovy Vary Region
# Kastina
# Katsina
# Kebbi
# Kedah
# Kerman
# Kermanshah
# Khanh Hoa
# Khenchela
# Khuzestan
# Kitui
# Kordestan
# Kuyavia-Pomerania
# Kwale County
# Kwara
# Kwazulu-Natal
# Kymenlaakso Hospital District
# Kyoto Prefecture
# Kyzylorda
# LA MAR
# LA UNION
# LAMAS
# LAMPA
# LEONCIO PRADO
# LUCAnaS
# LUYA
# La Convencion
# La Pampa
# La Paz
# La Union
# Laane
# Laane-Viru
# Laghouat
# Lagos
# Laguna
# Lanao Del Norte
# Lanao Del Sur
# Lanao del Norte
# Lanao del Sur
# Lansi-Pohja Hospital District
# Lapland
# Lappi Hospital District
# Las Tunas
# Leyte
# Liberec
# Liberec Region
# Limpopo
# Lisbon
# Ljubljana
# Lodz
# Loja
# Lorestan
# Lower Austria
# Lower Saxony
# Lower Silesia
# Lublin
# Lubusz
# Lucerne
# M'sila
# MANU
# MARANON
# MARISCAL LUZURIAGA
# MARISCAL RAMON Castilla
# MELGAR
# MOHO
# Macedonia
# Madeira
# Maguindanao
# Manabi
# Mangystau
# Marianao
# Marinduque
# Mariscal Caceres
# Mariscal Nieto
# Markazi
# Masbate
# Mascara
# Mash East
# Mash West
# Masovia
# Matabeleland North
# Matanzas
# Mayabeque
# Maynas
# Maysan
# Mazandaran
# Medea
# Mendoza
# Metro Manila
# Metropolitan Region
# Mila
# Misamis Occidental
# Misamis Oriental
# Misiones
# Moldavia
# Mombasa
# Mombasa or Nairobi
# Mombasa, Nairobi or Mandera
# Mombasa, Nairobi or Nyandarua
# Moravian-Silesian Region
# More og Romsdal
# Morona Santiago
# Morropon
# Morón
# Moscow City
# Mostaganem
# Moyobamba
# Mpumalanga
# NAZCA
# Nairobi County
# Nairobi, Mombasa or Homabay
# Najaf
# Nakhon Pathom
# Nara Prefecture
# Nasarawa
# National Capital Region (NCR)
# Navarre
# Negros Occidental
# Negros Oriental
# Netherlands
# Neuquen
# New Providence
# Niamey Capital District
# Nidwalden
# Nonthaburi
# Normandie
# Normandy
# Norte
# North Brabant
# North Caucasian
# North Chungcheong
# North Gyeongsang
# North Holland
# North Jeolla
# North Karelia Hospital District
# North Kazakhstan
# North Khorasan
# North Ostrobothnia Hospital District
# North West
# North Western
# Northern Region
# Northern Samar
# Nouvelle-Aquitaine
# Nueva Ecija
# Nueva Vizcaya
# OCROS
# OTUZCO
# Obwalden
# Occidental Mindoro
# Occitanie
# Ogun
# Olomouc
# Olomouc Region
# Ondo
# Opole
# Oran
# Oriental Mindoro
# Oromia
# Oruro
# Oslo
# Osun
# Ouargla
# Oum El Bouaghi
# Oxapampa
# Oyo
# Oyon
# PACHITEA
# PADRE ABAD
# PALLASCA
# PARURO
# PATAZ
# PAUCARTAmbo
# PICOTA
# PUERTO INCA
# Pacasmayo
# Paijat-Hame Hospital District
# Paita
# Palawan
# Palpa
# Pampanga
# Pangasinan
# Paraguari
# Pardubice
# Pardubice Region
# Parinacochas
# Parnu
# Pastaza
# Pays de la Loire
# Pichincha
# Pinar del Rio
# Pinar del Río
# Pirkanmaa Hospital District
# Pisco
# Placeta
# Plateau
# Playa
# Plzen
# Plzen Region
# Podlaskie
# Pohjois-Savo Hospital District
# Polva
# Pomabamba
# Pomerania
# Potosi
# Prachuap Khiri Khan
# Prague
# Principado de Asturias
# Provence-Alpes-Cote d'Azur
# Provence-Alpes-Cote d’Azur
# Pte Hayes
# QUISPIcaNCHI
# Qazvin
# Qom
# Quetzaltenango
# Quezon
# RECUAY
# REQUENA
# RODRIGUEZ DE MENDOZA
# Rapla
# Razavi Khorasan
# Region de Murcia
# Relizane
# Republic of Congo
# Rhineland-Palatinate
# Rio Negro
# Rioja
# Rivers
# Rizal
# Rizal Province
# Rogaland
# Romblon
# SAN ANTONIO DE PUTINA
# SAN IGNACIO
# SAN PABLO
# SAN ROMAN
# SANCHEZ CARRION
# SANDIA
# SATIPO
# SIHUAS
# SIN ESPECIFIcaR
# SNNPR
# Saare
# Sacatepequez
# Saint-Martin
# Salta
# Salzburg
# Samar
# San Cristóbal
# San Juan
# San Luis
# San Marcos
# San Miguel
# San Miguel del Padrón
# San Pedro
# Sancti Spiritu
# Sancti Spiritus
# Sancti Spirítus
# Sancti Spíritus
# Sankt Gallen
# Santa
# Santa Clara
# Santa Cruz
# Santa Elena
# Santa Fe
# Santa Marta
# Santa Marta DT y C
# Santa Rosa
# Sante Fe
# Santiago DE CHUCO
# Santiago Metropolitan Region
# Santiago de Cuba
# Santiago del Estero
# Sarangani
# Satakunta Hospital District
# Saxony
# Saxony-Anhalt
# Schwyz
# Sechura
# Sejong
# Selangor
# Semnan
# Seoul
# Setif
# Shymkent
# Siberia
# Sicily
# Sidi Bel Abbes
# Sihanoukville
# Silesia
# Sistan and Baluchestan
# Skikda
# Sodermanland
# Sokoto
# Somali
# Sorsogon
# Souk-Ahras
# South
# South Bohemian Region
# South Chungcheong
# South Cotabato
# South Gyeongsang
# South Holland
# South Jeolla
# South Karelia Hospital District
# South Khorasan
# South Korea
# South Moravian Region
# South Ostrobothnia Hospital District
# Southern
# Southern Region
# Spain
# Special
# Styria
# Subcarpathia
# Suchitepequez
# Sucumbios
# Sullana
# Sultan Kudarat
# Sulu
# Surigao Del Norte
# Sweden
# TAHUAMANU
# TALARA
# TARATA
# TARMA
# TOCACHE
# Taiwan
# Tambopata
# Tanga
# Taraba
# Tarlac
# Tarlac Province
# Tartu
# Tayacaja
# Tebessa
# Tehran
# Thanh Hoa
# Thurgau
# Thuringia
# Ticino
# Tierra del Fuego
# Tipaza
# Tissemsilt
# Tizi Ouzou
# Tlemcen
# Togichi
# Transbaikalia
# Trentino-Alto Adige
# Troms og Finnmark
# Trondelag
# Trujillo
# Tucuman
# Tyrol
# UNK
# URUBAMBA
# UTCUBAMBA
# Ukraine
# Ulsan
# United Kingdom
# Upper Austria
# Upper West Region
# Ural
# Usti nad Labem
# Usti nad Labem Region
# VICTOR FAJARDO
# VILCAS HUAMAN
# VIRU
# Vaasa Hospital District
# Valais
# Valencian Community
# Valga
# Valle
# Varsinais-Suomi Hospital District
# Vaud
# Vestfold og Telemark
# Vestland
# Vienna
# Viken
# Viljandi
# Villa Clara
# Vinh Phuc
# Volga
# Vorarlberg
# Voru
# Vysocina
# Vysocina Region
# Wakayama Prefecture
# Wallonia
# Warmia-Masuria
# West Azarbaijan
# West Pomerania
# Western Cape
# Wilayah Persekutuan Kuala Lumpur
# YAROWILCA
# YAULI
# YAUYOS
# YUNGAY
# YUNGUYO
# Yazd
# Yobe
# Zambales
# Zamboanga Del Sur
# Zamboanga del Sur
# Zamfara
# Zanjan
# Zarumilla
# Zealand
# Zhytomyr
# Zlin
# Zlin Region
# Zug
# Zurich
# azuay
# canar
# carchi
# chimborazo
# cotopaxi
# el oro
# esmeraldas
# estado de Mexico
# galapagos
# guayas
# imbabura
# loja
# manabi
# morona santiago
# napo
# orellana
# pastaza
# pichincha
# province of Havana
# santa elena
# santo domingo tsachilas
# sucumbios
# tungurahua
# zamora chinchipe
# Ñeembucu
# ñeembucu

# %% [markdown]
# # A Province is a country with its cities, coordinates are similar so we shifted it to province

# %%
data1.loc[data1.index==98036,'province']='Puerto Rico'
data1.loc[data1.index==59920,'province']='Puerto Rico'
data1.loc[data1.index==117041,'province']='Puerto Rico'
data1.loc[data1.index==258482,'province']='Puerto Rico'
data1.loc[data1.index==292150,'province']='Puerto Rico'

# %% [markdown]
# # Replaced rest of the countries

# %%
data1['country']=data1['country'].replace(['United States'],['US']) 
data1['country']=data1['country'].replace(['Democratic Republic of the Congo'],['Congo (Kinshasa)']) 
data1['country']=data1['country'].replace(['Republic of Congo'],['Congo (Brazzaville)']) 
data1['country']=data1['country'].replace(['South Korea'],['Korea, South']) 
data1['country']=data1['country'].replace(['Reunion'],['France'])
data1['country']=data1['country'].replace('Puerto Rico','US')
data1['country']=data1['country'].replace('Czech Republic','Czechia')

# %% [markdown]
# # making sure all strings are compared currectly

# %%
def toUpper(data):
    return data.upper()

data2['Province_State']=data2['Province_State'].astype(str)
data1['province']=data1['province'].astype(str)

data1['province']=data1['province'].apply(toUpper)
data2['Province_State']=data2['Province_State'].apply(toUpper)

data2['Country_Region']=data2['Country_Region'].astype(str)
data1['country']=data1['country'].astype(str)

data1['country']=data1['country'].apply(toUpper)
data2['Country_Region']=data2['Country_Region'].apply(toUpper)

# %% [markdown]
# # With our data ready we now Join it

# %%
CountrySum = data2.groupby(by=['Province_State','Country_Region']).sum()
CountryMean = data2.groupby(by=['Province_State','Country_Region']).mean()

# %%
for i in range(len(CountrySum)):
    CountrySum['Case-Fatality_Ratio'][i]= (CountrySum['Deaths'][i] / CountrySum['Confirmed'][i])*100
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
CountrySum['Incidence_Rate'] = CountryMean['Incidence_Rate']
CountrySum = CountrySum.drop(['Lat', 'Long_'],axis=1)

# %%
worldMerge = data1.merge(CountrySum,how='left',left_on=['province', 'country'], right_on=['Province_State','Country_Region'])

# %%
worldMerge = worldMerge.reset_index()

worldMerge.to_csv("finalData.csv", index = False)

# %%
worldMerge1 = worldMerge.head(int(len(worldMerge)/2))
worldMerge2 = worldMerge[int(len(worldMerge)/2):].reset_index()
worldMerge1.to_csv("finalDataPart1.csv", index = False)
worldMerge2.to_csv("finalDataPart2.csv", index = False)

# %%
# Out:
#          index        age     sex     province country  latitude  longitude  \
# 278681  278681  61.000000  557362       TUMBES    PERU  -3.55556  -80.42922
# 278682  278682  37.333333  557362        DELHI   INDIA  28.61474   77.20910
# 278683  278683  44.630769  557362  MAHARASHTRA   INDIA  18.94017   72.83483
# 278684  278684  50.930556  557362      GUJARAT   INDIA  22.46919   70.07095
# 278685  278685  44.630769  557362  MAHARASHTRA   INDIA  18.94017   72.83483
# ...        ...        ...     ...          ...     ...       ...        ...
# 557357  557357  56.000000  557362       CALLAO    PERU -12.04175  -77.09082
# 557358  557358  44.630769  557362  MAHARASHTRA   INDIA  18.94017   72.83483
# 557359  557359  44.630769  557362  MAHARASHTRA   INDIA  19.03681   73.01582
# 557360  557360  25.000000  557362   TAMIL NADU   INDIA  13.08362   80.28252
# 557361  557361  45.081081  557362    RAJASTHAN   INDIA  26.26691   73.03052
#
#        date_confirmation  additional_information  \
# 278681        30.04.2020                 Unknown
# 278682        18.05.2020  Matching MOHFW Numbers
# 278683        02.05.2020                 Unknown
# 278684        10.05.2020                 Unknown
# 278685        13.05.2020                 Unknown
# ...                  ...                     ...
# 557357        15.04.2020                 Unknown
# 557358        29.05.2020                 Unknown
# 557359        19.05.2020                 Unknown
# 557360        31.05.2020                 Unknown
# 557361        08.05.2020                 Unknown
#
#                                                    source          outcome  \
# 278681                                            Unknown  nonhospitalized
# 278682  https://twitter.com/ANI/status/126225567739047...        recovered
# 278683                       https://t.me/indiacovid/3848        recovered
# 278684  https://www.deshgujarat.com/2020/05/10/live-da...        recovered
# 278685  https://arogya.maharashtra.gov.in/pdf/ncovidep...     hospitalized
# ...                                                   ...              ...
# 557357                                            Unknown  nonhospitalized
# 557358  https://arogya.maharashtra.gov.in/pdf/ncovidep...        recovered
# 557359                                            Unknown        recovered
# 557360  https://stopcorona.tn.gov.in/wp-content/upload...     hospitalized
# 557361  https://twitter.com/ANI/status/125878720879583...        recovered
#
#         Confirmed   Deaths  Recovered    Active  Incidence_Rate  \
# 278681     6735.0    293.0        0.0    6442.0     2677.932406
# 278682   238828.0   4907.0   201671.0   32250.0     1276.409575
# 278683  1167496.0  31791.0   834432.0  301273.0      948.072083
# 278684   120336.0   3286.0   100974.0   16076.0      188.400627
# 278685  1167496.0  31791.0   834432.0  301273.0      948.072083
# ...           ...      ...        ...       ...             ...
# 557357    30730.0   1687.0        0.0   29043.0     2719.709709
# 557358  1167496.0  31791.0   834432.0  301273.0      948.072083
# 557359  1167496.0  31791.0   834432.0  301273.0      948.072083
# 557360   530908.0   8685.0   475717.0   46506.0      682.039258
# 557361   111290.0   1308.0    92265.0   17717.0      137.339636
#
#         Case-Fatality_Ratio
# 278681             4.350408
# 278682             2.054617
# 278683             2.723007
# 278684             2.730687
# 278685             2.723007
# ...                     ...
# 557357             5.489749
# 557358             2.723007
# 557359             2.723007
# 557360             1.635877
# 557361             1.175308
#
# [278681 rows x 17 columns]
